# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot

# %%
bf=pd.read_csv("C:/Users/harik/Downloads/BlackFriday.csv")
bf.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
bf.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
bf.shape
# Out:
# (537577, 12)

# %% [markdown]
# ### Data Cleaning

# %%
bf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
bf.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# #the data product_category_2 and  product_category_3 has null values which can't be dropped as its not feasible.So we can either consider dropping the entire column or not consider in our analysis

# %%
del bf['Product_Category_2']
del bf['Product_Category_3']

# %%
bf.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
bf['User_ID'].nunique()
# Out:
# 5891

# %%
bf['Product_ID'].nunique()
# Out:
# 3623

# %%
bf['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
bf['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
bf['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
bf['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
bf['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
bf['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
bf['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
bf['Purchase'].nunique()
# Out:
# 17959

# %%
for column in bf:
    print(column,bf[column].nunique())
# Out:
# User_ID 5891
# Product_ID 3623
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 17959

# %%
#total number of male and female's purchasing on black-friday-sale
bf['Gender'].value_counts()
# Out:
# M    405380
# F    132197
# Name: Gender, dtype: int64

# %%
#total number of different products purchased by each gender
bf.groupby('Gender')['Product_Category_1'].count().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Product_Category_1'>

# %%
#total number of different products purchased by each gender by each category product
bf.groupby('Product_Category_1')['Gender'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
#finding the total purchase amount by each gender
bf.groupby('Gender').sum()['Purchase']
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_17936\3541407225.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bf.groupby('Gender').sum()['Purchase']
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
bf.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct="%.2f")
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_17936\1026343937.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bf.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct="%.2f")
# <Axes: ylabel='Purchase'>

# %%
#Users and total number of products purchased by each users and sorting the values descending based on products purchased by user
bf_no=bf.groupby('User_ID')['Product_ID'].count()
bf_no.sort_values(ascending=False)
# Out:
# User_ID
# 1001680    1025
# 1004277     978
# 1001941     898
# 1001181     861
# 1000889     822
#            ...
# 1005608       6
# 1005810       6
# 1002111       6
# 1004991       6
# 1000708       5
# Name: Product_ID, Length: 5891, dtype: int64

# %%
#AVerage amount spent on products based on the gender
bf.groupby('Gender')['Purchase'].mean().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
bf.groupby('Age').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
for i in bf['Age'].unique():
    print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
#number of products available in different age group 
for i in bf['Age'].unique():
    print(i,":",len(bf[bf['Age']==i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %%
lst=[]
for i in bf['Age'].unique():
    lst.append([i,bf[bf['Age']==i]['Product_ID'].nunique()])
lst
data=pd.DataFrame(lst,columns=['Age','Products'])
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
#plotting the graph to identify number of unique products available for different age groups
data.plot(kind='bar',x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
#Average amount spent by each age groups
data1=bf.groupby('Age')['Purchase'].mean()
data1.plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
bf.groupby('Marital_Status').size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
#Marital status of customers in different age groups who purchased in the black friday sale
sns.countplot(data=bf,x='Age',hue='Marital_Status')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
#Gender analysis based on different age groups
import seaborn as sns
sns.countplot(data=bf,x='Age',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
#Gender analysis who purchased products on black friday sale 
bf.groupby('Gender').size().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: >

# %%
#Analyzing the amount of purchase by different people in different age groups
bf.groupby('Age')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
#Analyzing percentage of different products sold in different cities
bf.groupby('City_Category')['Product_ID'].count().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Product_ID'>

# %%
#Number of male and female in different Cities
sns.countplot(data=bf,x='City_Category',hue='Gender')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
#Number of maried and unmarried people in different Cities
sns.countplot(data=bf,x='City_Category',hue='Marital_Status')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
#Analyzing different categories of people who belong to different age and their genders
sns.countplot(data=bf,x='Gender',hue='Age')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#count of people staying in the cities for a specified amount of time
bf.groupby('Stay_In_Current_City_Years').size().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
#count of people who are staying in the cities for a specified number of years
sns.countplot(data=bf,x="City_Category",hue='Stay_In_Current_City_Years')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
#how many people who belong to different age groups belong to which city
sns.countplot(data=bf,x="City_Category",hue="Age")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
#total number of people occupied 
bf.groupby('Occupation').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
#what products are people buying based on their occupation
bf.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
bf.groupby('Occupation').nunique()['Product_ID']
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
#Age groups of people who are staying in the cities for a specified period of time
sns.countplot(data=bf,x='Stay_In_Current_City_Years',hue='Age')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
#Gender analysis based on the city stay for a specified period of time
sns.countplot(data=bf,x='Stay_In_Current_City_Years',hue='Gender')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
#plotting the marital status of people and their stays in the city for a specified period of time
sns.countplot(data=bf,x='Stay_In_Current_City_Years',hue='Marital_Status')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
bf.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
#purchases by people buying based on their occupation
bf.groupby('Occupation')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
#based on the occupation of the people finding the total amount spent by them
bf.groupby('Occupation')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
#marital status of people in different occupations
sns.countplot(data=bf,x="Occupation",hue="Marital_Status")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
#Gender analysis in different occupations
sns.countplot(data=bf,x="Occupation",hue="Gender")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
#How many products categories do we have?
bf.groupby('Product_Category_1').size().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
#how many purchases are done by people on different categories
bf.groupby('Product_Category_1')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
#Analyzing the city_category based on stay of the people in that locations?
sns.countplot(data=bf,x='Stay_In_Current_City_Years',hue='City_Category')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
#purchases made by people depending on the stay of the people in cities
bf.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar')
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_17936\651381992.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bf.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar')
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
#Top 10 sold product ids
bf.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
#top 10 products with highest purchases on black friday sales
bf.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
bf.groupby('Gender')['Marital_Status'].count()
# Out:
# Gender
# F    132197
# M    405380
# Name: Marital_Status, dtype: int64

# %%
sns.countplot(data=bf,x='Gender',hue='Marital_Status')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#creating a list based on the person's gender and finding if they are married or not
l=[]
for i in range(len(bf)):
    l.append(bf['Gender'][i]+"_"+str(bf['Marital_Status'][i]))

# %%
bf['Marital_gender']=l

# %%
#finding the people who are married based on gender and their purchases
sns.countplot(data=bf,x='Marital_gender')
# Out:
# <Axes: xlabel='Marital_gender', ylabel='count'>

# %%
#finding the people of different ages and their marital status based on gender
sns.countplot(data=bf,x='Age',hue='Marital_gender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
#finding the different product_categories and their marital status based on gender
sns.countplot(data=bf,x='Product_Category_1',hue='Marital_gender')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
bf.groupby('Marital_gender')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Marital_gender'>
